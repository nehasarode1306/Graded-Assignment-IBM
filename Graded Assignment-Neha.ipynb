# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Neha Sarode**
#
#
# I am currently working as an RPA Blue Prism Developer

# %% [markdown]
# *I am interested in Data Science because I love to gain insights from data and work on different models and networks*

# %% [markdown]
# ### This code adds the contents of an array

# %%
arr=[11,12,13]
ans = sum(arr)
print("Sum of the array",ans)
# Out:
# Sum of the array 36

# %% [markdown]
# 1. Apple
# 2. Orange
# 8. Mango
#
#
# - Carrot
# - Coriander
# - Cabbage
#
#
# > The first one is a list of my favourite fruits.
# > The second one is vegetables starting with C because i couldnt think of anything :P
